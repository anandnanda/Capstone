# %% [markdown]
# <a href="https://colab.research.google.com/github/anandnanda/Capstone/blob/main/Anand.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Testing

# %%
#import librariries
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dsTrain=pd.read_csv('/content/drive/MyDrive/AIML/CarDetection/Train Annotations.csv')

# %%
dsTrain.head()
# Out:
#   Image Name  Bounding Box coordinates  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0  00001.jpg                        39         116         569         375
# 1  00002.jpg                        36         116         868         587
# 2  00003.jpg                        85         109         601         381
# 3  00004.jpg                       621         393        1484        1096
# 4  00005.jpg                        14          36         133          99
#
#    Image class
# 0           14
# 1            3
# 2           91
# 3          134
# 4          106

# %%
dsTest=pd.read_csv('/content/drive/MyDrive/AIML/CarDetection/Test Annotation.csv')
dsTest.head()
# Out:
#   Image Name  Bounding Box coordinates  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0  00001.jpg                        30          52         246         147
# 1  00002.jpg                       100          19         576         203
# 2  00003.jpg                        51         105         968         659
# 3  00004.jpg                        67          84         581         407
# 4  00005.jpg                       140         151         593         339
#
#    Image class
# 0          181
# 1          103
# 2          145
# 3          187
# 4          185

# %%
dsTest.rename(columns={'Bounding Box coordinates': 'x0', 'Unnamed: 2': 'y0', 'Unnamed: 3': 'x1', 'Unnamed: 4': 'y1' }, inplace=True)
dsTest.head()
# Out:
#   Image Name   x0   y0   x1   y1  Image class
# 0  00001.jpg   30   52  246  147          181
# 1  00002.jpg  100   19  576  203          103
# 2  00003.jpg   51  105  968  659          145
# 3  00004.jpg   67   84  581  407          187
# 4  00005.jpg  140  151  593  339          185

# %%
dsTest.shape
# Out:
# (8041, 6)

# %%
dsTrain.rename(columns={'Bounding Box coordinates': 'x0', 'Unnamed: 2': 'y0', 'Unnamed: 3': 'x1', 'Unnamed: 4': 'y1' }, inplace=True)
dsTrain.head()
# Out:
#   Image Name   x0   y0    x1    y1  Image class
# 0  00001.jpg   39  116   569   375           14
# 1  00002.jpg   36  116   868   587            3
# 2  00003.jpg   85  109   601   381           91
# 3  00004.jpg  621  393  1484  1096          134
# 4  00005.jpg   14   36   133    99          106

# %%
dsTrain.shape
# Out:
# (8144, 6)

# %%
ds=pd.read_csv('/content/drive/MyDrive/AIML/CarDetection/Car names and make.csv',header=None)
ds.head()
# Out:
#                             0
# 0  AM General Hummer SUV 2000
# 1         Acura RL Sedan 2012
# 2         Acura TL Sedan 2012
# 3        Acura TL Type-S 2008
# 4        Acura TSX Sedan 2012

# %%
ds.shape
# Out:
# (196, 1)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       196 non-null    object
# dtypes: object(1)
# memory usage: 1.7+ KB
